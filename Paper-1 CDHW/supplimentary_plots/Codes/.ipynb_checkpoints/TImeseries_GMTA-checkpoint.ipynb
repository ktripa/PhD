# %%
import pygmt as gmt
import numpy as np
import pandas as pd
import os 
import matplotlib.pyplot as plt
import xarray as xr
# %matplotlib inline

# %%
df=pd.read_csv('L:/codes_paper1/figure4/data_figure4/Global_temp_anomaly_1850_2099.txt',sep='\t',header=None).to_numpy()

# %%
fig, ax = plt.subplots()
ax.plot(df[:,0], df[:,-1])

ax.set(ylabel=f"Global Mean Temperature Anomaly (\N{DEGREE SIGN}C)", xlabel='Years',
       title='')
ax.grid(color='k', linestyle='-', linewidth=0.5, alpha=0.5)

# fig.savefig("test.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17600/1634088312.py in <module>
#       7
#       8 # fig.savefig("test.png")
# ----> 9 plt.show(Method='external')
#
# ~\Anaconda3\envs\pygmt\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# TypeError: show() got an unexpected keyword argument 'Method'
