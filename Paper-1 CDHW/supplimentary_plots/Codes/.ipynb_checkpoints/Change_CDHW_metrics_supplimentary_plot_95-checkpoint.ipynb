# %%
import pygmt as gmt
import numpy as np
import pandas as pd
import os 
import matplotlib.pyplot as plt
import xarray as xr
# %matplotlib inline

# %% [markdown]
# ## Function to convert the latlon files to a xarray suited format

# %%
def Latlon_to_xarray2d_format(df,lat,lon):
    sh=np.shape(df)[1]-2
    datf=np.empty([sh,len(lat),len(lon)])
    datf[:]=np.NaN
    for sha in range(sh):
        for i in range(len(lon)):
            for j in range(len(lat)):
                z=np.where( (df[:,0]==lon[i]) & (df[:,1]==lat[j]) ) # z is  a tuple which contains one numpy array 
                if len(z[0])==1:  
                    datf[sha,j,i]=df[z,2+sha]
    return datf

# %% [markdown]
# ## Read the CSV file as a numpy array

# %% [markdown]
# #### CDHW Events

# %%
df=pd.read_csv('L:/codes_paper1/supplimentary_plots/Data_for_supplimentary_plots/Abs_Modified_numCDHWe.txt',sep='\t',header=None).to_numpy()

# print(df.shape)
lat=np.arange(-90,90,2)
lon=np.arange(-178,182,2)

datf=Latlon_to_xarray2d_format(df,lat,lon)
print(f"size of the data : {datf.shape}")
data1=xr.DataArray(data=datf[0,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
data1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20640/2738217489.py in <module>
# ----> 1 df=pd.read_csv('L:/codes_paper1/supplimentary_plots/Data_for_supplimentary_plots/Abs_Modified_numCDHWe.txt',sep='\t',header=None).to_numpy()
#       2
#       3 # print(df.shape)
#       4 lat=np.arange(-90,90,2)
#       5 lon=np.arange(-178,182,2)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Plot the observed CDHWe

# %%
fig=gmt.Figure()
fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25],projection="N8i", water="snow2")
gmt.makecpt(cmap="jet", series=[0, 1, 0.033])
fig.grdimage(grid=data1,nan_transparent=True, frame="f",shading=True,interpolation="b")
fig.colorbar(position='JMR+w6c/0.8c+v+e1c',
            frame=["a0.2f","x+l#CDHWe"],
            scale=1,
            )
fig.show()
fig.savefig('CDHWe_obs.png',transparent=True)
fig.savefig('L:/codes_paper1/supplimentary_plots/CDHWe_obs.png',transparent=True)
print(f"figure object: {fig}")
# Out:
# figure object: <pygmt.figure.Figure object at 0x0000029D3EA7B310>

# %%
fig = gmt.Figure()
gmt.makecpt(cmap="jet", series=[0, 6, 0.2])
with fig.subplot(
    nrows=3,
    ncols=2,
    figsize=("16c", "12c"),
    autolabel=False,
    frame=["f"],
    margins=["0.1c", "0.2c"],
#     title="Change in number of CDHW events",
):
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[0, 0])
    data1=xr.DataArray(data=datf
           [1,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[1, 0])
    data1=xr.DataArray(data=datf
           [2,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[2, 0])
    data1=xr.DataArray(data=datf
           [3,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[0, 1])
    data1=xr.DataArray(data=datf
           [4,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[1, 1])
    data1=xr.DataArray(data=datf
           [5,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[2, 1])
    data1=xr.DataArray(data=datf
           [6,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
fig.colorbar(position='x3.5c/-1.3c+w9c/0.6c+h+e1c',
            frame=["a1f","x+lNum_CDHW_events"],
            scale=1,
            )
fig.show()
fig.savefig('Abs_CDHWe_subplots.png',transparent=True)
fig.savefig('L:/codes_paper1/supplimentary_plots/Abs_CDHWe_subplots.png',transparent=True)

# %% [markdown]
# ## Plot the observed CDHWd

# %%
df=pd.read_csv('L:/codes_paper1/supplimentary_plots/Data_for_supplimentary_plots/Abs_Modified_numCDHWd.txt',sep='\t',header=None).to_numpy()

# print(df.shape)
lat=np.arange(-90,90,2)
lon=np.arange(-178,182,2)

datf=Latlon_to_xarray2d_format(df,lat,lon)
print(f"size of the data : {datf.shape}")

data1=xr.DataArray(data=datf[0,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
data1

fig=gmt.Figure()
fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25],projection="N8i", water="snow2")
gmt.makecpt(cmap="jet", series=[0, 10, 0.5])
fig.grdimage(grid=data1,nan_transparent=True, frame="f",shading=True,interpolation="b")
fig.colorbar(position='JMR+w6c/0.8c+v+e1c',
            frame=["a2f","x+l#CDHWd"],
            scale=1,
            )
fig.show()
fig.savefig('CDHWd_obs.png',transparent=True)
fig.savefig('L:/codes_paper1/supplimentary_plots/CDHWd_obs.png',transparent=True)
# Out:
# size of the data : (7, 90, 180)

# %%
fig = gmt.Figure()
gmt.makecpt(cmap="jet", series=[0, 60, 3])
with fig.subplot(
    nrows=3,
    ncols=2,
    figsize=("16c", "12c"),
    autolabel=False,
    frame=["f"],
    margins=["0.1c", "0.2c"],
#     title="Change in number of CDHW events",
):
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[0, 0])
    data1=xr.DataArray(data=datf[1,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[1, 0])
    data1=xr.DataArray(data=datf[2,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="l")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[2, 0])
    data1=xr.DataArray(data=datf[3,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="l")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[0, 1])
    data1=xr.DataArray(data=datf[4,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="l")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[1, 1])
    data1=xr.DataArray(data=datf[5,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[2, 1])
    data1=xr.DataArray(data=datf[6,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
fig.colorbar(position='x3.5c/-1.3c+w9c/0.6c+h+e1c',
            frame=["a10f","x+lCDHW_Days"],
            scale=1)
fig.show()
fig.savefig('Abs_CDHWd_subplots.png',transparent=True)
fig.savefig('L:/codes_paper1/supplimentary_plots/Abs_CDHWd_subplots.png',transparent=True)

# %% [markdown]
# ## Plot the observed Severity

# %%
df=pd.read_csv('L:/codes_paper1/supplimentary_plots/Data_for_supplimentary_plots/Abs_Modified_numCDHWs.txt',sep='\t',header=None).to_numpy()

# print(df.shape)
lat=np.arange(-90,90,2)
lon=np.arange(-178,182,2)

datf=Latlon_to_xarray2d_format(df,lat,lon)
print(f"size of the data : {datf.shape}")

data1=xr.DataArray(data=datf[0,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
data1

fig=gmt.Figure()
fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25],projection="N8i", water="snow2")
gmt.makecpt(cmap="jet", series=[0, 30, 3])
fig.grdimage(grid=data1,nan_transparent=True, frame="f",shading=True,interpolation="b")
fig.colorbar(position='JMR+w6c/0.8c+v+e1c',
            frame=["a5f","x+lSeverity"],
            scale=1,
            )
fig.show()
fig.savefig('CDHWs_obs.png',transparent=True)
fig.savefig('L:/codes_paper1/supplimentary_plots/CDHWs_obs.png',transparent=True)


## subplot

fig = gmt.Figure()
gmt.makecpt(cmap="jet", series=[0, 100, 5])
with fig.subplot(
    nrows=3,
    ncols=2,
    figsize=("16c", "12c"),
    autolabel=False,
    frame=["f"],
    margins=["0.1c", "0.2c"],
#     title="Change in number of CDHW events",
):
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[0, 0])
    data1=xr.DataArray(data=datf
           [1,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[1, 0])
    data1=xr.DataArray(data=datf
           [2,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[2, 0])
    data1=xr.DataArray(data=datf
           [3,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[0, 1])
    data1=xr.DataArray(data=datf
           [4,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[1, 1])
    data1=xr.DataArray(data=datf
           [5,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
    
    fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25], projection="N?", water="snow2", panel=[2, 1])
    data1=xr.DataArray(data=datf
           [6,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
    fig.grdimage(grid=data1,nan_transparent=True,frame="f",interpolation="b")
fig.colorbar(position='x3.5c/-1.3c+w9c/0.6c+h+e1c',
            frame=["a20f","x+lSeverity"],
            scale=1,
            )
fig.show()
fig.savefig('Abs_CDHWs_subplots.png',transparent=True)
fig.savefig('L:/codes_paper1/supplimentary_plots/Abs_CDHWs_subplots.png',transparent=True)
# Out:
# size of the data : (7, 90, 180)

# %%
fig=gmt.Figure()
with fig.subplot(nrows=3, ncols=2, figsize=("16c", "12c"), frame="lrtb"): 
    for j in range(3): 
        for i in range(2): 
            index = j * 2 + i  
            with fig.set_panel(panel=index): 
                data1=xr.DataArray(data=datf
                                   [index+1,:,:],dims=['x','y'],coords={'y':np.arange(-178,182,2),'x':np.arange(-90,90,2)})
                gmt.makecpt(cmap="jet", series=[0, 3.5, 3.5])
                fig.coast(shorelines="1/0.1p",region=[-180, 180, -66, 66.25],projection="N0/?", water="snow2")
                fig.grdimage(grid=data1,cmap="jet",nan_transparent=True,frame="f",interpolation="b")
                
#                 fig.coast(shorelines=True)
fig.colorbar(position='x5c/2c+w6c/0.8c+h',
            frame=["af","x+lChange_CDHWe"],
            scale=1,
            )
                
fig.show()
# fig.savefig('ChangeIn_CDHWe_subpplots.png',transparent=True)
# Out:
# colorbar [ERROR]: CPT <stdin> has no z-slices!
# [Session pygmt-session (185)]: Error returned from GMT API: GMT_CPT_READ_ERROR (8)
# [Session pygmt-session (185)]: Error returned from GMT API: GMT_CPT_READ_ERROR (8)
